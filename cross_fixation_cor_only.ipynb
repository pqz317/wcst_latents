# %%
# %load_ext autoreload
# %autoreload 2

import s3fs
import pandas as pd
import os
import numpy as np

from lfads import LFADS_Net, LFADS_SingleSession_Net
import torch
import torch.optim as opt
from scheduler import LFADS_Scheduler
from plotter import Plotter
from trainer import RunManager

import yaml

from synthetic_data import LorenzSystem, EmbeddedLowDNetwork
from objective import SVLAE_Loss, LFADS_Loss, LogLikelihoodPoisson, LogLikelihoodPoissonSimplePlusL1, LogLikelihoodPoissonSimple, LogLikelihoodGaussian

from utils import load_parameters
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import pickle
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /usr/local/lib/python3.8/dist-packages/torchvision/image.so: undefined symbol: _ZNK3c1010TensorImpl36is_contiguous_nondefault_policy_implENS_12MemoryFormatE
#   warn(f"Failed to load image Python extension: {e}")

# %%
species = 'nhp'
subject = 'SA'
exp = 'WCST'
session = 20180802  # this is the session for which there are spikes at the moment. 

NHP_WCST_DIR = 'nhp-lfp/wcst-preprocessed/'


# grab behavioral data, spike data, trial numbers. 
fs = s3fs.S3FileSystem()
behavior_file = os.path.join(NHP_WCST_DIR, "rawdata", "sub-" + str(subject), "sess-" + str(session), "behavior", "sub-" + str(subject) + "_sess-" + str(session) + "_object_features.csv")
behavior_data = pd.read_csv(fs.open(behavior_file))
valid_beh = behavior_data[behavior_data.Response.isin(["Correct"])]   
valid_beh = valid_beh[valid_beh.TrialNumber >= 57]

# %%
pre_interval = 0
post_interval = 350
interval_size = 50
frs = pd.read_pickle(fs.open(f"l2l.pqz317.scratch/firing_rates_{pre_interval}_crossfixation_{post_interval}_{interval_size}_bins.pickle"))
frs = frs[frs.TrialNumber.isin(valid_beh.TrialNumber)]

# %%
# get data in trials x time x neurons
num_time_bins = len(frs["TimeBins"].unique())
num_units = len(frs["UnitID"].unique())
num_trials = len(frs["TrialNumber"].unique())
sorted = frs.sort_values(by=["UnitID", "TimeBins", "TrialNumber"])
# currently in neurons x time x trials
spike_data = sorted["SpikeCounts"].to_numpy().reshape((num_units, num_time_bins, num_trials))
# want trials x time x neurons
spike_data = np.transpose(spike_data, (2, 1, 0))

# %%
spike_data.shape
# Out:
# (946, 7, 58)

# %%
# device = 'cuda' if torch.cuda.is_available() else 'cpu'; print(device)
device = 'cpu'
train_idxs, valid_idxs = train_test_split(np.arange(spike_data.shape[1]), train_size=0.8)
train_spikes = spike_data[:, train_idxs, :]

valid_spikes = spike_data[:, valid_idxs, :]

train_data  = torch.Tensor(train_spikes).to(device)
valid_data  = torch.Tensor(valid_spikes).to(device)
train_ds    = torch.utils.data.TensorDataset(train_data)
valid_ds    = torch.utils.data.TensorDataset(valid_data)
train_dl    = torch.utils.data.DataLoader(train_ds, batch_size = 50, shuffle=True)
valid_dl    = torch.utils.data.DataLoader(valid_ds, batch_size = valid_data.shape[0])

# %%
hyperparameter_path = 'lfads_cross_fixation_hyperparams.yaml'
hyperparams = load_parameters(hyperparameter_path)
model = LFADS_SingleSession_Net(
    input_size           = 58,
    factor_size          = hyperparams['model']['factor_size'],
    g_encoder_size       = hyperparams['model']['g_encoder_size'],
    c_encoder_size       = hyperparams['model']['c_encoder_size'],
    g_latent_size        = hyperparams['model']['g_latent_size'],
    u_latent_size        = hyperparams['model']['u_latent_size'],
    controller_size      = hyperparams['model']['controller_size'],
    generator_size       = hyperparams['model']['generator_size'],
    prior                = hyperparams['model']['prior'],
    clip_val             = hyperparams['model']['clip_val'],
    dropout              = hyperparams['model']['dropout'],
    do_normalize_factors = hyperparams['model']['normalize_factors'],
    max_norm             = hyperparams['model']['max_norm'],
    device               = device
).to(device)

# %%
dt = 0.05
loglikelihood = LogLikelihoodPoisson(dt=dt, device=device)
objective = LFADS_Loss(
    loglikelihood=loglikelihood,
    loss_weight_dict={
        "kl": hyperparams['objective']["kl"],
        "l2": hyperparams["objective"]["l2"]},
    l2_con_scale=hyperparams["objective"]["l2_con_scale"],
    l2_gen_scale=hyperparams["objective"]["l2_gen_scale"]
).to(device)

# %%
optimizer = opt.Adam([p for p in model.parameters() if p.requires_grad],
                     lr=hyperparams['optimizer']['lr_init'],
                     betas=hyperparams['optimizer']['betas'],
                     eps=hyperparams['optimizer']['eps'])

scheduler = LFADS_Scheduler(optimizer      = optimizer,
                            mode           = 'min',
                            factor         = hyperparams['scheduler']['scheduler_factor'],
                            patience       = hyperparams['scheduler']['scheduler_patience'],
                            verbose        = True,
                            threshold      = 1e-4,
                            threshold_mode = 'abs',
                            cooldown       = hyperparams['scheduler']['scheduler_cooldown'],
                            min_lr         = hyperparams['scheduler']['lr_min'])

# %%
# transforms  = trf.Compose([])

run_manager = RunManager(model      = model,
                         objective  = objective,
                         optimizer  = optimizer,
                         scheduler  = scheduler,
                         train_dl   = train_dl,
                         valid_dl   = valid_dl,
                         transforms = None,  # transforms,
                         writer     = None,
                         plotter    = None,
                         max_epochs = 100,
                         save_loc   = "data/lfadscrosscoronly",
                         do_health_check = False)

# %%
run_manager.run()
with open("data/cross_cor_only_loss_data.pickle", "wb") as f:
    pickle.dump(run_manager.loss_dict, f)
# Out:
# Epoch     1, Epoch time = 0.239 s, Loss (train, valid):  recon (127.933, 46.786), kl (2.967, 0.586), total (133.788, 51.783), l2 (2.888)
# Epoch     2, Epoch time = 0.238 s, Loss (train, valid):  recon (104.455, 45.130), kl (1.257, 0.415), total (109.960, 49.588), l2 (4.249)
# Epoch     3, Epoch time = 0.245 s, Loss (train, valid):  recon (102.917, 44.907), kl (0.608, 0.351), total (107.361, 48.862), l2 (3.836)
# Epoch     4, Epoch time = 0.242 s, Loss (train, valid):  recon (102.137, 44.750), kl (0.722, 0.499), total (106.267, 48.443), l2 (3.408)
# Epoch     5, Epoch time = 0.257 s, Loss (train, valid):  recon (101.675, 44.201), kl (0.904, 0.558), total (105.594, 47.586), l2 (3.016)
# Epoch     6, Epoch time = 0.238 s, Loss (train, valid):  recon (101.335, 44.324), kl (0.969, 0.569), total (104.971, 47.385), l2 (2.666)
# Epoch     7, Epoch time = 0.237 s, Loss (train, valid):  recon (101.109, 44.341), kl (1.135, 0.652), total (104.595, 47.196), l2 (2.351)
# Epoch     8, Epoch time = 0.241 s, Loss (train, valid):  recon (101.063, 44.341), kl (1.070, 0.550), total (104.206, 46.830), l2 (2.073)
# Epoch     9, Epoch time = 0.246 s, Loss (train, valid):  recon (100.827, 44.312), kl (1.226, 0.484), total (103.883, 46.509), l2 (1.830)
# Epoch    10, Epoch time = 0.248 s, Loss (train, valid):  recon (100.941, 44.059), kl (1.070, 0.570), total (103.628, 46.143), l2 (1.618)
# Epoch    11, Epoch time = 0.236 s, Loss (train, valid):  recon (100.704, 43.926), kl (1.218, 0.565), total (103.354, 45.830), l2 (1.431)
# Epoch    12, Epoch time = 0.237 s, Loss (train, valid):  recon (100.695, 44.208), kl (1.143, 0.497), total (103.104, 45.890), l2 (1.266)
# Epoch    13, Epoch time = 0.247 s, Loss (train, valid):  recon (100.685, 44.198), kl (1.207, 0.522), total (103.014, 45.774), l2 (1.121)
# Epoch    14, Epoch time = 0.236 s, Loss (train, valid):  recon (100.591, 44.403), kl (1.242, 0.543), total (102.829, 45.884), l2 (0.997)
# Epoch    15, Epoch time = 0.248 s, Loss (train, valid):  recon (100.503, 44.342), kl (1.220, 0.529), total (102.611, 45.706), l2 (0.889)
# Epoch    16, Epoch time = 0.279 s, Loss (train, valid):  recon (100.632, 44.658), kl (1.235, 0.458), total (102.661, 45.861), l2 (0.794)
# Epoch    17, Epoch time = 0.237 s, Loss (train, valid):  recon (100.470, 44.312), kl (1.206, 0.457), total (102.385, 45.442), l2 (0.709)
# Epoch    18, Epoch time = 0.253 s, Loss (train, valid):  recon (100.417, 44.348), kl (1.239, 0.444), total (102.293, 45.397), l2 (0.638)
# Epoch    19, Epoch time = 0.256 s, Loss (train, valid):  recon (100.244, 44.279), kl (1.265, 0.400), total (102.084, 45.224), l2 (0.574)
# Epoch    20, Epoch time = 0.253 s, Loss (train, valid):  recon (100.285, 44.593), kl (1.260, 0.479), total (102.064, 45.563), l2 (0.518)
# Epoch    21, Epoch time = 0.229 s, Loss (train, valid):  recon (100.278, 44.864), kl (1.245, 0.469), total (101.992, 45.780), l2 (0.468)
# Epoch    22, Epoch time = 0.214 s, Loss (train, valid):  recon (100.370, 44.545), kl (1.227, 0.441), total (102.022, 45.391), l2 (0.425)
# Epoch    23, Epoch time = 0.243 s, Loss (train, valid):  recon (100.158, 44.263), kl (1.292, 0.422), total (101.837, 45.055), l2 (0.388)
# Epoch    24, Epoch time = 0.236 s, Loss (train, valid):  recon (100.169, 44.338), kl (1.268, 0.408), total (101.793, 45.086), l2 (0.356)
# Epoch    25, Epoch time = 0.237 s, Loss (train, valid):  recon (100.242, 44.269), kl (1.321, 0.462), total (101.888, 45.041), l2 (0.324)
# Epoch    26, Epoch time = 0.255 s, Loss (train, valid):  recon (100.356, 44.333), kl (1.268, 0.475), total (101.923, 45.093), l2 (0.299)
# Epoch    27, Epoch time = 0.236 s, Loss (train, valid):  recon (100.280, 44.608), kl (1.309, 0.395), total (101.864, 45.264), l2 (0.275)
# Epoch    28, Epoch time = 0.256 s, Loss (train, valid):  recon (100.169, 44.121), kl (1.289, 0.515), total (101.710, 44.881), l2 (0.252)
# Epoch    29, Epoch time = 0.241 s, Loss (train, valid):  recon (100.004, 44.494), kl (1.349, 0.409), total (101.591, 45.130), l2 (0.237)
# Epoch    30, Epoch time = 0.240 s, Loss (train, valid):  recon (100.017, 44.504), kl (1.354, 0.364), total (101.593, 45.084), l2 (0.222)
# Epoch    31, Epoch time = 0.240 s, Loss (train, valid):  recon (99.964, 44.353), kl (1.292, 0.399), total (101.465, 44.955), l2 (0.209)
# Epoch    32, Epoch time = 0.241 s, Loss (train, valid):  recon (100.048, 44.322), kl (1.289, 0.429), total (101.534, 44.943), l2 (0.198)
# Epoch    33, Epoch time = 0.242 s, Loss (train, valid):  recon (100.117, 44.542), kl (1.319, 0.359), total (101.623, 45.082), l2 (0.186)
# Epoch    34, Epoch time = 0.240 s, Loss (train, valid):  recon (100.107, 44.249), kl (1.258, 0.410), total (101.544, 44.832), l2 (0.178)
# Epoch    35, Epoch time = 0.245 s, Loss (train, valid):  recon (100.035, 44.618), kl (1.291, 0.409), total (101.495, 45.194), l2 (0.169)
# Epoch    36, Epoch time = 0.245 s, Loss (train, valid):  recon (99.927, 44.788), kl (1.346, 0.476), total (101.436, 45.426), l2 (0.163)
# Epoch    37, Epoch time = 0.269 s, Loss (train, valid):  recon (100.038, 44.393), kl (1.315, 0.435), total (101.513, 44.985), l2 (0.160)
# Epoch    38, Epoch time = 0.237 s, Loss (train, valid):  recon (99.887, 44.582), kl (1.325, 0.398), total (101.365, 45.134), l2 (0.153)
# Epoch    39, Epoch time = 0.238 s, Loss (train, valid):  recon (100.003, 44.633), kl (1.255, 0.453), total (101.408, 45.234), l2 (0.151)
# Epoch    40, Epoch time = 0.238 s, Loss (train, valid):  recon (99.921, 44.412), kl (1.242, 0.438), total (101.309, 44.995), l2 (0.146)
# Epoch    41, Epoch time = 0.247 s, Loss (train, valid):  recon (99.810, 44.240), kl (1.373, 0.394), total (101.326, 44.776), l2 (0.143)
# Epoch    42, Epoch time = 0.235 s, Loss (train, valid):  recon (99.910, 44.288), kl (1.353, 0.463), total (101.405, 44.892), l2 (0.141)
# Epoch    43, Epoch time = 0.239 s, Loss (train, valid):  recon (99.888, 44.337), kl (1.329, 0.378), total (101.357, 44.853), l2 (0.140)
# Epoch    44, Epoch time = 0.243 s, Loss (train, valid):  recon (99.749, 44.570), kl (1.350, 0.337), total (101.236, 45.043), l2 (0.137)
# Epoch    45, Epoch time = 0.236 s, Loss (train, valid):  recon (99.858, 44.546), kl (1.380, 0.455), total (101.373, 45.136), l2 (0.135)
# Epoch    46, Epoch time = 0.252 s, Loss (train, valid):  recon (99.750, 44.376), kl (1.352, 0.440), total (101.237, 44.952), l2 (0.135)
# Epoch    47, Epoch time = 0.235 s, Loss (train, valid):  recon (99.692, 44.450), kl (1.259, 0.420), total (101.086, 45.002), l2 (0.135)
# Epoch    48, Epoch time = 0.309 s, Loss (train, valid):  recon (99.734, 44.386), kl (1.343, 0.438), total (101.209, 44.956), l2 (0.132)
# Epoch    49, Epoch time = 0.242 s, Loss (train, valid):  recon (99.720, 44.597), kl (1.373, 0.375), total (101.224, 45.105), l2 (0.131)
# Epoch    50, Epoch time = 0.236 s, Loss (train, valid):  recon (99.719, 44.631), kl (1.335, 0.325), total (101.186, 45.085), l2 (0.132)
# Epoch    51, Epoch time = 0.241 s, Loss (train, valid):  recon (99.754, 44.607), kl (1.391, 0.353), total (101.274, 45.088), l2 (0.129)
# Epoch    52, Epoch time = 0.236 s, Loss (train, valid):  recon (100.022, 44.464), kl (1.312, 0.462), total (101.461, 45.050), l2 (0.128)
# Epoch    53, Epoch time = 0.240 s, Loss (train, valid):  recon (99.914, 44.478), kl (1.362, 0.437), total (101.403, 45.042), l2 (0.126)
# Epoch 00054: reducing learning rate of group 0 to 9.5000e-03.
# Epoch    54, Epoch time = 0.242 s, Loss (train, valid):  recon (99.895, 44.330), kl (1.340, 0.435), total (101.363, 44.894), l2 (0.128)
# Epoch    55, Epoch time = 0.246 s, Loss (train, valid):  recon (99.841, 44.892), kl (1.419, 0.365), total (101.390, 45.390), l2 (0.130)
# Epoch    56, Epoch time = 0.237 s, Loss (train, valid):  recon (99.766, 44.782), kl (1.397, 0.373), total (101.293, 45.286), l2 (0.130)
# Epoch    57, Epoch time = 0.236 s, Loss (train, valid):  recon (99.680, 44.405), kl (1.338, 0.366), total (101.149, 44.900), l2 (0.131)
# Epoch    58, Epoch time = 0.239 s, Loss (train, valid):  recon (99.634, 44.356), kl (1.378, 0.409), total (101.143, 44.894), l2 (0.131)
# Epoch    59, Epoch time = 0.245 s, Loss (train, valid):  recon (99.674, 44.442), kl (1.345, 0.426), total (101.147, 44.999), l2 (0.129)
# Epoch    60, Epoch time = 0.238 s, Loss (train, valid):  recon (99.625, 44.263), kl (1.412, 0.457), total (101.164, 44.850), l2 (0.128)
# Epoch    61, Epoch time = 0.240 s, Loss (train, valid):  recon (99.642, 44.609), kl (1.314, 0.436), total (101.085, 45.174), l2 (0.129)
# Epoch    62, Epoch time = 0.241 s, Loss (train, valid):  recon (99.582, 44.483), kl (1.406, 0.423), total (101.117, 45.033), l2 (0.129)
# Epoch    63, Epoch time = 0.238 s, Loss (train, valid):  recon (99.590, 44.364), kl (1.360, 0.448), total (101.077, 44.939), l2 (0.128)
# Epoch    64, Epoch time = 0.246 s, Loss (train, valid):  recon (99.541, 44.383), kl (1.424, 0.413), total (101.092, 44.923), l2 (0.127)
# Epoch    65, Epoch time = 0.229 s, Loss (train, valid):  recon (99.658, 44.462), kl (1.383, 0.349), total (101.169, 44.937), l2 (0.128)
# Epoch    66, Epoch time = 0.237 s, Loss (train, valid):  recon (99.612, 44.581), kl (1.415, 0.373), total (101.155, 45.082), l2 (0.128)
# Epoch    67, Epoch time = 0.227 s, Loss (train, valid):  recon (99.630, 44.122), kl (1.378, 0.450), total (101.134, 44.699), l2 (0.126)
# Epoch    68, Epoch time = 0.232 s, Loss (train, valid):  recon (99.698, 44.353), kl (1.377, 0.430), total (101.200, 44.908), l2 (0.125)
# Epoch    69, Epoch time = 0.237 s, Loss (train, valid):  recon (99.547, 44.371), kl (1.374, 0.379), total (101.047, 44.875), l2 (0.126)
# Epoch    70, Epoch time = 0.247 s, Loss (train, valid):  recon (99.607, 44.860), kl (1.362, 0.405), total (101.094, 45.393), l2 (0.125)
# Epoch    71, Epoch time = 0.240 s, Loss (train, valid):  recon (99.544, 44.324), kl (1.473, 0.426), total (101.143, 44.875), l2 (0.126)
# Epoch    72, Epoch time = 0.284 s, Loss (train, valid):  recon (99.551, 44.488), kl (1.322, 0.462), total (100.998, 45.073), l2 (0.124)
# Epoch    73, Epoch time = 0.235 s, Loss (train, valid):  recon (99.597, 44.735), kl (1.378, 0.384), total (101.096, 45.241), l2 (0.121)
# Epoch    74, Epoch time = 0.249 s, Loss (train, valid):  recon (99.501, 44.797), kl (1.330, 0.323), total (100.954, 45.244), l2 (0.123)
# Epoch    75, Epoch time = 0.239 s, Loss (train, valid):  recon (99.533, 44.563), kl (1.345, 0.380), total (101.000, 45.066), l2 (0.122)
# Epoch    76, Epoch time = 0.240 s, Loss (train, valid):  recon (99.504, 44.633), kl (1.356, 0.414), total (100.983, 45.170), l2 (0.123)
# Epoch    77, Epoch time = 0.251 s, Loss (train, valid):  recon (99.408, 44.578), kl (1.430, 0.445), total (100.961, 45.147), l2 (0.123)
# Epoch    78, Epoch time = 0.258 s, Loss (train, valid):  recon (99.645, 44.604), kl (1.384, 0.406), total (101.151, 45.132), l2 (0.122)
# Epoch    79, Epoch time = 0.276 s, Loss (train, valid):  recon (99.586, 44.653), kl (1.384, 0.378), total (101.093, 45.153), l2 (0.122)
# Epoch    80, Epoch time = 0.250 s, Loss (train, valid):  recon (99.458, 44.473), kl (1.432, 0.434), total (101.012, 45.028), l2 (0.122)
# Epoch 00081: reducing learning rate of group 0 to 9.0250e-03.
# Epoch    81, Epoch time = 0.286 s, Loss (train, valid):  recon (99.413, 44.484), kl (1.454, 0.406), total (100.987, 45.008), l2 (0.119)
# Epoch    82, Epoch time = 0.252 s, Loss (train, valid):  recon (99.521, 44.321), kl (1.366, 0.408), total (101.007, 44.847), l2 (0.120)
# Epoch    83, Epoch time = 0.246 s, Loss (train, valid):  recon (99.491, 44.464), kl (1.339, 0.363), total (100.948, 44.948), l2 (0.118)
# Epoch    84, Epoch time = 0.237 s, Loss (train, valid):  recon (99.469, 44.653), kl (1.460, 0.352), total (101.049, 45.123), l2 (0.120)
# Epoch    85, Epoch time = 0.242 s, Loss (train, valid):  recon (99.458, 44.565), kl (1.464, 0.400), total (101.042, 45.085), l2 (0.120)
# Epoch    86, Epoch time = 0.226 s, Loss (train, valid):  recon (99.316, 44.366), kl (1.414, 0.411), total (100.851, 44.899), l2 (0.121)
# Epoch    87, Epoch time = 0.243 s, Loss (train, valid):  recon (99.506, 44.545), kl (1.420, 0.436), total (101.048, 45.102), l2 (0.122)
# Epoch    88, Epoch time = 0.239 s, Loss (train, valid):  recon (99.465, 44.509), kl (1.384, 0.469), total (100.971, 45.099), l2 (0.121)
# Epoch    89, Epoch time = 0.238 s, Loss (train, valid):  recon (99.384, 44.243), kl (1.386, 0.434), total (100.891, 44.795), l2 (0.121)
# Epoch    90, Epoch time = 0.241 s, Loss (train, valid):  recon (99.475, 44.456), kl (1.407, 0.444), total (101.002, 45.019), l2 (0.120)
# Epoch    91, Epoch time = 0.251 s, Loss (train, valid):  recon (99.475, 44.647), kl (1.460, 0.436), total (101.053, 45.202), l2 (0.118)
# Epoch    92, Epoch time = 0.271 s, Loss (train, valid):  recon (99.358, 44.652), kl (1.439, 0.399), total (100.916, 45.170), l2 (0.119)
# Epoch    93, Epoch time = 0.226 s, Loss (train, valid):  recon (99.398, 44.596), kl (1.318, 0.509), total (100.835, 45.224), l2 (0.119)
# Epoch    94, Epoch time = 0.263 s, Loss (train, valid):  recon (99.437, 44.917), kl (1.412, 0.378), total (100.966, 45.413), l2 (0.118)
# Epoch    95, Epoch time = 0.239 s, Loss (train, valid):  recon (99.356, 44.688), kl (1.352, 0.424), total (100.826, 45.230), l2 (0.118)
# Epoch    96, Epoch time = 0.255 s, Loss (train, valid):  recon (99.451, 44.498), kl (1.345, 0.425), total (100.915, 45.040), l2 (0.119)
# Epoch    97, Epoch time = 0.239 s, Loss (train, valid):  recon (99.377, 44.716), kl (1.403, 0.397), total (100.897, 45.230), l2 (0.117)
# Epoch    98, Epoch time = 0.234 s, Loss (train, valid):  recon (99.498, 44.600), kl (1.391, 0.460), total (101.006, 45.174), l2 (0.116)
# Epoch    99, Epoch time = 0.243 s, Loss (train, valid):  recon (99.362, 44.564), kl (1.376, 0.396), total (100.853, 45.074), l2 (0.115)
# Epoch   100, Epoch time = 0.247 s, Loss (train, valid):  recon (99.421, 44.398), kl (1.444, 0.488), total (100.982, 45.002), l2 (0.116)

# %%
loss_file = open("data/cross_cor_only_loss_data.pickle", "rb")
loss_dict = pickle.load(loss_file)
fig, ax = plt.subplots()
# ax.plot(run_manager.loss_dict["train"]["total"], label="Total Loss Train")
ax.plot(loss_dict["valid"]["total"], label="Total Loss Valid")
ax.legend()

# %%
best = torch.load("data/lfadscrosscoronlycheckpoints/best.pth")
best_model = LFADS_SingleSession_Net(
    input_size           = 58,
    factor_size          = hyperparams['model']['factor_size'],
    g_encoder_size       = hyperparams['model']['g_encoder_size'],
    c_encoder_size       = hyperparams['model']['c_encoder_size'],
    g_latent_size        = hyperparams['model']['g_latent_size'],
    u_latent_size        = hyperparams['model']['u_latent_size'],
    controller_size      = hyperparams['model']['controller_size'],
    generator_size       = hyperparams['model']['generator_size'],
    prior                = hyperparams['model']['prior'],
    clip_val             = hyperparams['model']['clip_val'],
    dropout              = hyperparams['model']['dropout'],
    do_normalize_factors = hyperparams['model']['normalize_factors'],
    max_norm             = hyperparams['model']['max_norm'],
    device               = device
).to(device)
best_model.load_state_dict(best["net"])
# Out:
# <All keys matched successfully>

# %%
out = best_model(torch.Tensor(spike_data))

# %%
fig, ax = plt.subplots()
posterior_means = best_model.g_posterior_mean.detach().numpy()
# ax.plot(run_manager.loss_dict["train"]["total"], label="Total Loss Train")
ax.scatter(posterior_means[:, 0], posterior_means[:, 1])

# %%
def label_trials(block_group):
    block_len = len(block_group)
    block_group["TrialUntilRuleChange"] = block_len - block_group["TrialAfterRuleChange"]
    last_eight = block_group[block_group["TrialUntilRuleChange"] <= 8]
    return last_eight
block_groups = valid_beh.groupby(["BlockNumber"], as_index=False)
only_last_eight = block_groups.apply(label_trials).reset_index()
idx_cyan = np.argwhere(
    np.isin(valid_beh.TrialNumber.values, only_last_eight.TrialNumber.values) & 
    (valid_beh.CurrentRule.values == "CYAN")
)[:,0]
idx_triangle = np.argwhere(
    np.isin(valid_beh.TrialNumber.values, only_last_eight.TrialNumber.values) & 
    (valid_beh.CurrentRule.values == "TRIANGLE")
)[:,0]
idx_last_eight = np.argwhere(np.isin(valid_beh.TrialNumber.values, only_last_eight.TrialNumber.values))

# %%
fig, ax = plt.subplots()
posterior_means = best_model.g_posterior_mean.detach().numpy()
# ax.plot(run_manager.loss_dict["train"]["total"], label="Total Loss Train")
ax.scatter(posterior_means[:, 0], posterior_means[:, 1])
ax.scatter(posterior_means[idx_cyan, 0], posterior_means[idx_cyan, 1], label="Cyan last eight")
ax.scatter(posterior_means[idx_triangle, 0], posterior_means[idx_triangle, 1], label="Triangle last eight")
ax.legend()

# %%
fig, ax = plt.subplots()
posterior_means = best_model.g_posterior_mean.detach().numpy()
# ax.plot(run_manager.loss_dict["train"]["total"], label="Total Loss Train")
ax.scatter(posterior_means[:, 0], posterior_means[:, 1])
ax.scatter(posterior_means[idx_last_eight, 0], posterior_means[idx_last_eight, 1], label="Last Eights")
ax.legend()
